# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
from openai import OpenAI
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display

# %%
# constants

MODEL_GROQ = 'llama-3.3-70b-versatile'
MODEL_LLAMA = 'llama3.2'

GROQ_BASE_URL = "https://api.groq.com/openai/v1"
OLLAMA_BASE_URL = "http://localhost:11434/v1"

# %%
# set up environment

load_dotenv(override=True)

groq_client = OpenAI(
    base_url=GROQ_BASE_URL,
    api_key=os.getenv("GROQ_API_KEY")
)

ollama_client = OpenAI(
    base_url=OLLAMA_BASE_URL,
    api_key="ollama"
)

systen_prompt = "You are a helpful assisstabnt that is veyr knowledgable about coding and answers in markdown"

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming

response = groq_client.chat.completions.create(
    model=MODEL_GROQ,
    messages=[
        {"role": "system", "content": systen_prompt},
        {"role": "user", "content": question}
    ]
)

result = response.choices[0].message.content
display(Markdown(result))
# Out:
# ### Explanation of the Code
# ```python
# yield from {book.get("author") for book in books if book.get("author")}
# ```
# This line of code is a generator expression that yields unique authors from a collection of books.
#
# ### Breakdown
# * `book.get("author")`: This method retrieves the value associated with the key `"author"` from each `book` dictionary. If the key does not exist, it returns `None` by default.
# * `{...}`: This is a set comprehension, which creates a set containing unique authors.
# * `for book in books`: This loop iterates over each `book` in the `books` collection.
# * `if book.get("author")`: This condition filters out books that do not have an author (i.e., `book.get("author")` returns `None` or an empty string).
# * `yield from`: This yields each item from the resulting set of authors, allowing the code to be used in a generator context.
#
# ### Example Use Case
# ```python
# books = [
#     {"title": "Book 1", "author": "Author A"},
#     {"title": "Book 2", "author": "Author B"},
#     {"title": "Book 3", "author": "Author A"},
#     {"title": "Book 4"},
# ]
#
# unique_authors = (author for author in {book.get("author") for book in books if book.get("author")})
# for author in unique_authors:
#     print(author)
# ```
# Output:
# ```
# Author A
# Author B
# ```
# In this example, the code prints each unique author from the `books` collection, ignoring books without an author and duplicates.
#
# ### Why Use This Code
# This code is useful when:
#
# * You need to process a large collection of books and want to efficiently retrieve unique authors.
# * You want to ignore books without an author or duplicates.
# * You need to use the code in a generator context, such as in a larger data processing pipeline.

# %%
# Get Llama 3.2 to answer

response = ollama_client.chat.completions.create(
    model=MODEL_LLAMA,
    messages=[
        {"role": "system", "content": systen_prompt},
        {"role": "user", "content": question}
    ]
)

result = response.choices[0].message.content
display(Markdown(result))
# Out:
# **Generators and List Comprehensions**
# ======================================
#
# The given code snippet utilizes both yield from and list comprehensions to process a collection of book objects.
#
# ### Breakdown:
#
# - **`for book in books if book.get("author")`**:
#     - This loop iterates over the `books` collection, but it only includes items where the "author" key exists.
#     - The `if` clause acts as a filter to ensure that each book has an author.
#
# - **`{book.get("author") for book in ...}`**:
#     - This is a list comprehension. It generates a new iterable (in this case, a set or dictionary) containing the "author" values from all books for which "author" was present.
#     - The `get()` method ensures that if any book lacks an author, it will produce `None` instead of raising a KeyError.
#
# - **`yield from {book.get("author") ...}`**:
#     - This utilizes the yield from keyword to delegate yielding back all authors found in the previous iteration without creating unnecessary Python stacks.
#     - By using `yield from`, this expression yields immediately, rather than producing all values and then yielding them at once.
#
# ### Result:
#
# The code effectively generates a sequence of author names (as strings or other hashable objects) where each name is associated with its corresponding book.
#
# **Example Use Case:**
# ```python
# def get_authors(books):
#     yield from {book.get("author") for book in books if book.get("author")}
#
# # Example usage:
# books = [
#     {"title": "Book 1", "author": "John Doe"},
#     {"title": "Book 2"}
# ]
#
# for author in get_authors(books):
#     print(author)
# ```
# This will output the following (assuming authors and titles have been properly configured):
#
# ```
# John Doe
# None
# ```
